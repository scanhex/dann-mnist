# %%
import numpy as np
import torch

# %%
base_dir = './datasets/cmnist/fgbg_cmnist_cpr0.5-0.5'
train_x = np.load(base_dir + '/train_x.npy')
test_x = np.load(base_dir + '/test_x.npy')

# %%
import matplotlib.pyplot as plt
for i in range(16):
    plt.subplot(4,4,1 + i)
    plt.imshow(test_x[i,:,:,:].transpose(1,2,0))
plt.show()
for i in range(16):
    plt.subplot(4,4,1 + i)
    plt.imshow(train_x[i,:,:,:].transpose(1,2,0))

# %%
print(train_x[0].shape)
print(train_x[:][0].mean())
print(train_x[:][1].mean())
print(train_x[:][2].mean())
print(train_x[:][0].std())
print(train_x[:][1].std())
print(train_x[:][2].std())
# Out:
# (3, 28, 28)
# 0.9006944165876306
# 0.8890065702844677
# 0.9225712355493335
# 0.2737345475857668
# 0.28947692267716757
# 0.23929832766437883
